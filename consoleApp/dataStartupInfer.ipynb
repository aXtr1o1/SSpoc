# %%
import pandas as pd
import numpy as np
import openai
import faiss

# %%
f = open('apiKey.bin', 'r')
apiKey = f.read()

# %%
openai.api_key =apiKey
f.close()

# %%
def get_embedding(text, model="text-embedding-ada-002"):
    response = openai.Embedding.create(input=[text], model=model)
    return response['data'][0]['embedding']

# %%
def load_csv(file_path):
    return pd.read_csv(file_path)

# %%
def create_faiss_index(df, text_column):
    embeddings = np.array([get_embedding(str(row)) for row in df[text_column]])
    dimension = len(embeddings[0])
    index = faiss.IndexFlatL2(dimension)
    index.add(embeddings)
    return index, embeddings, df

# %%
def search_faiss(index, query, top_k=10):
    query_embedding = np.array([get_embedding(query)])
    distances, indices = index.search(query_embedding, top_k)
    return indices[0]

# %%
def format_for_gpt(results, df):
    result_data = []
    for idx in results:
        result_data.append(df.iloc[idx].to_dict())
    return "\n".join([str(row) for row in result_data])

# %%
def query_gpt(query, results, df):
    formatted_results = format_for_gpt(results, df)
    prompt = f"""
    You are an AI assistant analyzing investor & startup data.
    Based on the following retrieved data, answer the user query.

    Retrieved Data:
    {formatted_results}

    User Query: "{query}"
    """

    response = openai.chat_completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "system", "content": "You analyze investor & startup data."},
                  {"role": "user", "content": prompt}],
        temperature=0.3
    )

    return response.choices[0].message.content

# %%
def perform_query(query, df, text_column="Company Name", top_k=10):
    index, embeddings, df = create_faiss_index(df, text_column)
    indices = search_faiss(index, query, top_k)
    results = indices  # Get the indices from FAISS search
    answer = query_gpt(query, results, df)
    return answer

# %%
df = load_csv("dataStuff/synthDataStartup.csv")

# %%
df
# Out:
#                 Company Name                Founder Name  \
# 0                TechLabs596      Santosh1878 Venkat1878
# 1         TechInnovations442            Arun450 Rajan450
# 2          CyberDynamics1100  Vishnu1092 Subramanian1092
# 3               AgroLabs1445      Karthik431 Krishnan431
# 4           SmartSystems1094           Hari855 Murthy855
# ...                      ...                         ...
# 1495  QuantumInnovations1294      Suresh1483 Sridhar1483
# 1496       FutureSystems1449      Karthik371 Krishnan371
# 1497               AquaAI800      Santosh1248 Venkat1248
# 1498          EcoDynamics709        Santosh638 Venkat638
# 1499             InnoEdge903      Mohan1769 Sundaram1769
#
#                                       Email        Designation  Mobile Number  \
# 0               santosh1878@techlabs596.com  Managing Director     9260756423
# 1            arun450@techinnovations442.com                CEO     9202075872
# 2          vishnu1092@cyberdynamics1100.com                CTO     8613702655
# 3               karthik431@agrolabs1445.com            Founder     9592930839
# 4              hari855@smartsystems1094.com  Managing Director     9711332659
# ...                                     ...                ...            ...
# 1495  suresh1483@quantuminnovations1294.com            Founder     8072330589
# 1496       karthik371@futuresystems1449.com  Managing Director     8265279913
# 1497              santosh1248@aquaai800.com                CEO     7618081494
# 1498          santosh638@ecodynamics709.com                CTO     7049538257
# 1499              mohan1769@innoedge903.com            Founder     8086623620
#
#                              Website         City  \
# 0                www.techlabs596.com  Kanyakumari
# 1         www.techinnovations442.com        Erode
# 2          www.cyberdynamics1100.com       Trichy
# 3               www.agrolabs1445.com  Tirunelveli
# 4           www.smartsystems1094.com        Salem
# ...                              ...          ...
# 1495  www.quantuminnovations1294.com         Ooty
# 1496       www.futuresystems1449.com      Chennai
# 1497               www.aquaai800.com      Vellore
# 1498          www.ecodynamics709.com   Coimbatore
# 1499             www.innoedge903.com      Madurai
#
#                                 Brief about the Company   I am a  \
# 0     TechLabs596 is an innovative venture focusing ...  Startup
# 1     TechInnovations442 is an innovative venture fo...     MSME
# 2     CyberDynamics1100 is an innovative venture foc...  Startup
# 3     AgroLabs1445 is an innovative venture focusing...     MSME
# 4     SmartSystems1094 is an innovative venture focu...  Startup
# ...                                                 ...      ...
# 1495  QuantumInnovations1294 is an innovative ventur...     MSME
# 1496  FutureSystems1449 is an innovative venture foc...  Startup
# 1497  AquaAI800 is an innovative venture focusing on...     MSME
# 1498  EcoDynamics709 is an innovative venture focusi...  Startup
# 1499  InnoEdge903 is an innovative venture focusing ...     MSME
#
#              Legal Entity Current Stage of Startup                  Sector  \
# 0      One Person Company              Pre-Revenue           Cybersecurity
# 1          Public Limited                 Ideation            Green Energy
# 2     Sole Proprietorship         Revenue & Growth  Gaming & Entertainment
# 3         Private Limited                Expansion               Logistics
# 4                     LLP          Mature Business                  Energy
# ...                   ...                      ...                     ...
# 1495   One Person Company                 Ideation              Healthcare
# 1496       Public Limited         Revenue & Growth           Cybersecurity
# 1497  Sole Proprietorship                Expansion            Green Energy
# 1498      Private Limited          Mature Business  Gaming & Entertainment
# 1499                  LLP                Prototype               Logistics
#
#      I want to apply for funding
# 0                             No
# 1                            Yes
# 2                             No
# 3                            Yes
# 4                             No
# ...                          ...
# 1495                         Yes
# 1496                          No
# 1497                         Yes
# 1498                          No
# 1499                         Yes
#
# [1500 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['Company Name', 'Founder Name', 'Email', 'Designation', 'Mobile Number',
#        'Website', 'City', 'Brief about the Company', 'I am a', 'Legal Entity',
#        'Current Stage of Startup', 'Sector', 'I want to apply for funding'],
#       dtype='object')

# %%
query = "I need the List of Startups that are in IT Sector & in Pre Revenue Stage"

# %%
outResult = perform_query(query, df)
outResult
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 outResult = perform_query(query, df)
#       2 outResult
#
# Cell In[42], line 2, in perform_query(query, df, text_column, top_k)
#       1 def perform_query(query, df, text_column="Company Name", top_k=10):
# ----> 2     index, embeddings, df = create_faiss_index(df, text_column)
#       3     indices = search_faiss(index, query, top_k)
#       4     results = indices  # Get the indices from FAISS search
#
# Cell In[38], line 2, in create_faiss_index(df, text_column)
#       1 def create_faiss_index(df, text_column):
# ----> 2     embeddings = np.array([get_embedding(str(row)) for row in df[text_column]])
#       3     dimension = len(embeddings[0])
#       4     index = faiss.IndexFlatL2(dimension)
#
# Cell In[36], line 2, in get_embedding(text, model)
#       1 def get_embedding(text, model="text-embedding-ada-002"):
# ----> 2     response = openai.Embedding.create(input=[text], model=model)
#       3     return response['data'][0]['embedding']
#
# File ~/Library/Python/3.13/lib/python/site-packages/openai/api_resources/embedding.py:33, in Embedding.create(cls, *args, **kwargs)
#      31 while True:
#      32     try:
# ---> 33         response = super().create(*args, **kwargs)
#      35         # If a user specifies base64, we'll just return the encoded string.
#      36         # This is only for the default case.
#      37         if not user_provided_encoding_format:
#
# File ~/Library/Python/3.13/lib/python/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~/Library/Python/3.13/lib/python/site-packages/openai/api_requestor.py:288, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)
#     286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#     291         params=params,
#     292         supplied_headers=headers,
#     293         files=files,
#     294         stream=stream,
#     295         request_id=request_id,
#     296         request_timeout=request_timeout,
#     297     )
#     298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File ~/Library/Python/3.13/lib/python/site-packages/openai/api_requestor.py:596, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     594     _thread_context.session_create_time = time.time()
#     595 try:
# --> 596     result = _thread_context.session.request(
#     597         method,
#     598         abs_url,
#     599         headers=headers,
#     600         data=data,
#     601         files=files,
#     602         stream=stream,
#     603         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     604         proxies=_thread_context.session.proxies,
#     605     )
#     606 except requests.exceptions.Timeout as e:
#     607     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File ~/Library/Python/3.13/lib/python/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Library/Python/3.13/lib/python/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Library/Python/3.13/lib/python/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Library/Python/3.13/lib/python/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/Library/Python/3.13/lib/python/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Library/Python/3.13/lib/python/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File /usr/local/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /usr/local/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:350, in HTTPResponse.begin(self)
#     347 else:
#     348     raise UnknownProtocol(version)
# --> 350 self.headers = self.msg = parse_headers(self.fp)
#     352 if self.debuglevel > 0:
#     353     for hdr, val in self.headers.items():
#
# File /usr/local/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:249, in parse_headers(fp, _class)
#     246 """Parses only RFC2822 headers from a file pointer."""
#     248 headers = _read_headers(fp)
# --> 249 return _parse_header_lines(headers, _class)
#
# File /usr/local/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:243, in _parse_header_lines(header_lines, _class)
#     232 """
#     233 Parses only RFC2822 headers from header lines.
#     234
#    (...)
#     240
#     241 """
#     242 hstring = b''.join(header_lines).decode('iso-8859-1')
# --> 243 return email.parser.Parser(_class=_class).parsestr(hstring)
#
# File /usr/local/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/email/parser.py:64, in Parser.parsestr(self, text, headersonly)
#      56 def parsestr(self, text, headersonly=False):
#      57     """Create a message structure from a string.
#      58
#      59     Returns the root of the message structure.  Optional headersonly is a
#    (...)
#      62     the file.
#      63     """
# ---> 64     return self.parse(StringIO(text), headersonly=headersonly)
#
# File /usr/local/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/email/parser.py:53, in Parser.parse(self, fp, headersonly)
#      51     feedparser._set_headersonly()
#      52 while data := fp.read(8192):
# ---> 53     feedparser.feed(data)
#      54 return feedparser.close()
#
# File /usr/local/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/email/feedparser.py:176, in FeedParser.feed(self, data)
#     174 """Push more data into the parser."""
#     175 self._input.push(data)
# --> 176 self._call_parse()
#
# File /usr/local/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/email/feedparser.py:180, in FeedParser._call_parse(self)
#     178 def _call_parse(self):
#     179     try:
# --> 180         self._parse()
#     181     except StopIteration:
#     182         pass
#
# File /usr/local/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/email/feedparser.py:240, in FeedParser._parsegen(self)
#     237     headers.append(line)
#     238 # Done with the headers, so parse them and figure out what we're
#     239 # supposed to see in the body of the message.
# --> 240 self._parse_headers(headers)
#     241 # Headers-only parsing is a backwards compatibility hack, which was
#     242 # necessary in the older parser, which could raise errors.  All
#     243 # remaining lines in the input are thrown into the message body.
#     244 if self._headersonly:
#
# File /usr/local/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/email/feedparser.py:492, in FeedParser._parse_headers(self, lines)
#     490     lastheader, lastvalue = '', []
#     491 # Check for envelope header, i.e. unix-from
# --> 492 if line.startswith('From '):
#     493     if lineno == 0:
#     494         # Strip off the trailing newline
#     495         mo = NLCRE_eol.search(line)
#
# KeyboardInterrupt:
